# %%
from PIL import Image
img = Image.open('/content/SYnthetic-Copy.webp')
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=600x400>

# %%
from PIL import Image
img = Image.open('/content/asian-beautiful-two-women-shopping-260nw-2436660923.webp')
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=390x280>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Sample_Consumer_Behavior_Dataset.csv")
df.head(20)
# Out:
#     Customer ID  Age  Gender Item Purchased     Category  \
# 0          2744   62    Male         Blouse  Accessories
# 1          1659   22    Male        Sandals  Accessories
# 2          2439   21    Male          Scarf     Clothing
# 3          3407   27    Male          Socks  Accessories
# 4          3748   31  Female          Shoes  Accessories
# 5          3716   61  Female         Gloves  Accessories
# 6          2708   51    Male           Belt  Accessories
# 7           942   24    Male         Blouse     Clothing
# 8          2396   62    Male        T-shirt     Clothing
# 9          3806   47    Male       Backpack    Outerwear
# 10          572   25    Male         Gloves     Clothing
# 11         3539   36  Female          Dress  Accessories
# 12         3091   32    Male       Backpack  Accessories
# 13         2314   55    Male       Backpack  Accessories
# 14         2143   36  Female           Coat  Accessories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             100 non-null    int64
#  1   Age                     100 non-null    int64
#  2   Gender                  100 non-null    object
#  3   Item Purchased          100 non-null    object
#  4   Category                100 non-null    object
#  5   Purchase Amount (USD)   100 non-null    int64
#  6   Location                100 non-null    object
#  7   Size                    100 non-null    object
#  8   Color                   100 non-null    object
#  9   Season                  100 non-null    object
#  10  Review Rating           100 non-null    float64
#  11  Subscription Status     100 non-null    object
#  12  Shipping Type           100 non-null    object
#  13  Discount Applied        100 non-null    object
# ...

# %%
df.describe(include='all')
# Out:
#         Customer ID         Age Gender Item Purchased  Category  \
# count    100.000000  100.000000    100            100       100
# unique          NaN         NaN      2             25         4
# top             NaN         NaN   Male        T-shirt  Clothing
# freq            NaN         NaN     66              9        54
# mean    1930.160000   46.230000    NaN            NaN       NaN
# std     1121.452546   14.051029    NaN            NaN       NaN
# min      114.000000   18.000000    NaN            NaN       NaN
# 25%      932.250000   36.750000    NaN            NaN       NaN
# 50%     2062.000000   46.500000    NaN            NaN       NaN
# 75%     2803.000000   58.000000    NaN            NaN       NaN
# max     3806.000000   69.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD)     Location Size     Color Season  \
# count               100.00000          100  100       100    100
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount' })

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# Create a column age_group:

# %%
labels =['Young adult','Adult','Middle aged','Senior']
df['age_group'] = pd.qcut(df['age'],q=4,labels=labels)

# %%
df[['age','age_group']].head(20)
# Out:
#     age    age_group
# 0    62       Senior
# 1    22  Young adult
# 2    21  Young adult
# 3    27  Young adult
# 4    31  Young adult
# 5    61       Senior
# 6    51  Middle aged
# 7    24  Young adult
# 8    62       Senior
# 9    47  Middle aged
# 10   25  Young adult
# 11   36  Young adult
# 12   32  Young adult
# 13   55  Middle aged
# 14   36  Young adult
# 15   57  Middle aged
# 16   37        Adult
# 17   61       Senior
# 18   69       Senior
# 19   43        Adult

# %% [markdown]
# Create a column purchase_frequency_days:

# %%
frequency_mapping ={
    'Fornightly':14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['frequency_of_purchases','purchase_frequency_days']].head(20)
# Out:
#    frequency_of_purchases  purchase_frequency_days
# 0                Annually                    365.0
# 1               Bi-Weekly                     14.0
# 2          Every 3 Months                     90.0
# 3                 Monthly                     30.0
# 4               Quarterly                     90.0
# 5                Annually                    365.0
# 6               Quarterly                     90.0
# 7             Fortnightly                      NaN
# 8                Annually                    365.0
# 9                Annually                    365.0
# 10              Quarterly                     90.0
# 11               Annually                    365.0
# 12              Bi-Weekly                     14.0
# 13               Annually                    365.0
# 14                Monthly                     30.0
# 15         Every 3 Months                     90.0
# 16            Fortnightly                      NaN
# ...

# %%
df[['discount_applied','promo_code_used']].head(20)
# Out:
#    discount_applied promo_code_used
# 0               Yes              No
# 1               Yes             Yes
# 2                No             Yes
# 3               Yes              No
# 4                No              No
# 5               Yes              No
# 6                No              No
# 7                No              No
# 8               Yes              No
# 9               Yes             Yes
# 10               No             Yes
# 11               No             Yes
# 12               No             Yes
# 13              Yes             Yes
# 14              Yes             Yes
# 15               No             Yes
# 16              Yes             Yes
# 17               No             Yes
# 18              Yes              No
# 19              Yes              No

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# np.False_

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group',
#        'purchase_frequency_days'],
#       dtype='object')

# %%
import plotly.express as px
px.histogram(df, x="frequency_of_purchases", opacity=.5, nbins=100,title="frequency of purchases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['promo_code_used'].value_counts()
# Out:
# promo_code_used
# No     58
# Yes    42
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(data=df, x='promo_code_used', palette='summer')
# Out:
# /tmp/ipython-input-2402043748.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='promo_code_used', ylabel='count'>

# %%
df['discount_applied'].value_counts()
# Out:
# discount_applied
# No     53
# Yes    47
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='discount_applied', palette='mako')
# Out:
# /tmp/ipython-input-1162006753.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='discount_applied', ylabel='count'>

# %%
px.histogram(df, x="location", opacity=.5, nbins=100,title="The location ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# %%
bar = plt.figure(figsize=(5,5))
sns.countplot(x='season', data = df, palette=['CadetBlue','Thistle','SandyBrown','pink'])
plt.title('Season of purchasing')
# Out:
# /tmp/ipython-input-3366443191.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0.5, 1.0, 'Season of purchasing')

# %%
import plotly.express as px

# %%
fig = px.pie(
    df,
    names = 'age_group',
    title = 'Customer Distribution By Age_Group',
    color_discrete_sequence=px.colors.sequential.Sunset,
    hole= 0.3
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a new DataFrame with the necessary columns and rename 'Payment Method'
df= df[['Payment Method']].copy()
df.columns = ['payment_method']

fig = px.pie(
    df,
    names = 'payment_method',
    title = 'Customer Distribution for Payment Method',
    color_discrete_sequence=px.colors.sequential.Sunset,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group',
#        'purchase_frequency_days'],
#       dtype='object')

# %%
sns.pairplot(data=df, hue='gender',palette='mako');

# %%
plt.figure(figsize=(4,5))

# %%
ax = sns.violinplot(x='gender', y='age', data=df, palette='pastel')
# Out:
# /tmp/ipython-input-3502052037.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
